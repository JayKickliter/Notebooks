# %% [markdown]
# # Polyphase Resampling

# %%
using Gadfly
using DataFrames
import IPPDSP

set_default_plot_size(20cm, 20cm/golden);

# %% [markdown]
# # Support Functions

# %% [markdown]
# ### `polyize( h, interploation)`
#
# Reorders a vector of FIR filter taps into a polyphase filterbank (PFB).
#
# Say you have 12 filter taps, and want to interpolate by 4. Polyize turns:
#
#     h0, h1, h2, h3, h4, h5, h6, h7, h8, h9, h10, h11
#
# into:
#
#     h0  h1  h2   h3
#     h4  h5  h6   h7
#     h8  h9  h10  h11
#
# Each column is a phase of the PFB. In this example, we are interploating by 4, so there are 4 columns. The numbe of taps in each phase depends on how many taps you provide. If the taps are not an integer multiple of interpolation, `polyize` will fill the gaps with 0's.

# %%
function polyize{T}( h::Vector{T}, interpolation )
    hLen         = length( h )
    tapsPerPhase = int( ceil( hLen/interpolation ))
    pfbSize = tapsPerPhase * interpolation
    # check that the vector is an integer multiple of interpolation
    if hLen != pfbSize 
        hExtended             = similar( h, pfbSize )
        hExtended[1:hLen]     = h
        hExtended[hLen+1:end] = 0
        h                     = hExtended
    end
    nFilters     = interpolation
    hLen         = length( h )
    tapsPerPhase = int( hLen/nFilters )
    pfb          = reshape( h, nFilters, tapsPerPhase )'
end
# Out:
# polyize (generic function with 1 method)

# %% [markdown]
# ### `areApprox( x1, x2 )`
#
# A vectoried version of Base.isapprox. We're going to use this to check that the output of the native interpolator is close enough to IPP's interpolator.

# %%
function areApprox( x1::Vector, x2::Vector )
    Nx1 = length( x1 )
    Nx2 = length( x2 )    
    
    Nx1 == Nx2 || throw( DimensionMismatch("x1 & x2 must be the equal length vectors") )
    
    for i = 1:Nx1
        isapprox( x1[i], x2[i] ) || error( "Something when wrong at index ", i )
    end
end
# Out:
# areApprox (generic function with 1 method)

# %% [markdown]
# # Interploator

# %%
function interpolate{T}( PFB::Array{T, 2}, x::Vector{T} )
    (Ntaps, Nφ) = size( PFB )           # each column is a phase of the PFB, the rows hold the individual taps
    Nx          = length( x )           # number of input items
    Ny          = Nx * Nφ
    y           = similar( x, Nx * Nφ ) # Ny = Nx * Nφ
    
    for Xn = 1:Ntaps-1, φ = 1:Nφ        # until Xn == Ntaps, x[Xn-m+1] would reach out of bounds 
                                        # this first loop limits Xn-m+1 to a minimum of 1
        Yn          = Nφ*(Xn-1)+φ
        accumulator = zero(T)

        for Tn = 1:Xn                   # for each tap in phase[n]
            @inbounds accumulator += PFB[Tn, φ] * x[Xn-Tn+1]
        end
        y[Yn] = accumulator
    end
    
    PFB = flipud(PFB)
    
    for Xn = Ntaps:Nx, φ = 1:Nφ         # no longer in danger of stepping out of bounds
        
        XnBase      = Xn-Ntaps               
        Yn          = Nφ*(Xn-1)+φ
        accumulator = zero(T)        
                
        @simd for Tn = 1:Ntaps
            @inbounds accumulator += PFB[Tn, φ] * x[XnBase + Tn]
        end
        
        y[Yn] = accumulator
    end

    return y
end

interpolate( h, x, interpolation ) = interpolate( polyize( h, interpolation ), x )
# Out:
# interpolate (generic function with 2 methods)

# %% [markdown]
# ## Interpolate Sanity Check

# %%
T  = Float32
Nt = 32
Nx = 100_000
L  = 4

h = IPPDSP.lowpass( T, Nt, 0.5/L, true )
x = rand( T, Nx )

@time ippResult = IPPDSP.filt( h, x, L, 1 )

@time nativeResult = interpolate( h, x, L )
areApprox( ippResult, nativeResult )

#df = DataFrame( IPP = ippResult, Native = interpolate )
# Out:
# ...
# elapsed time: 0.
# 057321401 seconds (3437728 bytes allocated)
# elapsed time:
# 0.231309751 seconds (7971356 bytes allocated)

# %% [markdown]
# # Rational Resampler
#
# ![Rational Resampling Diagram](http://cnx.org/content/m10443/latest/m10443fig3.png "Rational Resampling Diagram")[source](http://cnx.org/content/m10443/latest/)

# %%
function resample{T}( PFB::Array{T, 2}, x::Vector{T}, ratio::Rational )
    
    (Ntaps, Nφ) = size( PFB ) # each column is a phase of the PFB, the rows hold the individual taps
    L    = num(ratio)
    M    = den( ratio )    
    xLen = length( x )        # number of input items    
    
    xLen * L % M == 0 || error("signal length * interpolation mod decimation must be 0")    
    
    yLen = int(xLen*L/M)
    y    = zeros( T, yLen )
        
    for m = 0:yLen-1
        
        φ    = mod( m*M, L)
        nm   = int( floor( m*M / L ))
        kMax = nm < Ntaps ? nm+1 : Ntaps
        acc  = zero(T)

        # @printf( "\n\nφ = %d", φ+1 )
        # @printf( "\tnm = %d", nm+1 )
        # @printf( "\tkMax = %d\n", kMax)
        # @printf( "y[%d] =", m+1 )
        
        
        for k = 0:kMax-1
            # @printf( "\tPFB[%d, %d] * x[%d]", k+1, φ+1, nm+1-k )
            # @printf( "\t%f * %f", PFB[k+1, φ+1], x[nm+1-k] )
            acc += PFB[ k+1, φ+1 ] * x[ nm+1-k ]
        end
        
        # @printf( "\ny[%d] = %f", m+1, acc )
        
        y[m+1] = acc
    
    end

    return y
end
# Out:
# resample (generic function with 1 method)

# %% [markdown]
# ## `resample()` Sanity Check

# %%
T  = Float32
L  = 3
M  = 5
Nt = L*M
Nx = 5*M
Ny = int(Nx*L/M)
y  = zeros(T, Ny)

# h = IPPDSP.lowpass( T, Nt, 0.49/min(L,M), true )
# h = ones(T, Nt)
# x = zeros(T, Nx)
# x[4] = 1
# h = T[1:Nt]
# x = T[1.0:Nx]
x = rand(T, Nx)
h = rand(T, Nt)


ippResult = IPPDSP.filt( h, x, L, M )

h = polyize( h, L )
display(h)
nativeInefficient = interpolate(h, x)
y = [ nativeInefficient[i] for i in 1:M:length(nativeInefficient) ]
nativeResult = resample( h, x, L//M )
areApprox( ippResult, nativeResult )

df = DataFrame( IPP=ippResult, Inefficient=y, Native=nativeResult, Δ=ippResult-nativeResult )
# Out:
# 5x3 Array{Float32,2}:
#  0.785462  0.406296  0.455604
#  0.371622  0.330137  0.0515036
#  0.652773  0.816628  0.161511
#  0.905026  0.721956  0.57666
#  0.564152  0.05054   0.548237
# 15x4 DataFrame
# |-------|----------|-------------|----------|-------------|
# | Row # | IPP      | Inefficient | Native   | Δ           |
# | 1     | 0.733769 | 0.733769    | 0.733769 | 0.0         |
# | 2     | 0.352475 | 0.352475    | 0.352475 | 0.0         |
# | 3     | 1.69159  | 1.69159     | 1.69159  | -1.19209e-7 |
# | 4     | 1.54663  | 1.54663     | 1.54663  | -1.19209e-7 |
# | 5     | 1.18388  | 1.18388     | 1.18388  | 0.0         |
# | 6     | 1.21255  | 1.21255     | 1.21255  | -1.19209e-7 |
# | 7     | 2.03044  | 2.03044     | 2.03044  | 2.38419e-7  |
# | 8     | 0.812474 | 0.812474    | 0.812474 | 0.0         |
# | 9     | 1.2946   | 1.2946      | 1.2946   | 0.0         |
# | 10    | 1.63382  | 1.63382     | 1.63382  | 0.0         |
# ...

# %% [markdown]
# # Tests

# %% [markdown]
# ## Speed

# %%
function testspeed( Nsamples, Ntaps, interpolation )

    nTests      = length(Nsamples)*length(Ntaps)
    
    timeData = DataFrame( 
                Samples=DataArray(Int, nTests),
                Taps=DataArray(Int, nTests),
                NativeTime=DataArray(Float64, nTests),
                IPPTime=DataArray(Float64, nTests),
                Relative=DataArray(Float64, nTests) )    

    index      = 0
    
    for nt in Ntaps
    nt = int(nt)

    h = IPPDSP.lowpass( Float64, nt, 0.5/interpolation, true )

        for nx = Nsamples            
            nx = int(nx)
            index += 1

            timeData[index, 1] = nx
            timeData[index, 2] = nt

            nx = int(nx)
            x  = rand( typeof(h[1]), nx )        

            
            t = time()
            gc()
            polyAns = interpolate( h, x, interpolation )
            tPoly = time()-t
            timeData[index, 3] = tPoly
                                
            t = time()
            gc()
            ippAns = IPPDSP.filt( h, x, interpolation, 1 )
            tIPP = time()-t
            timeData[index, 4] = tIPP

            timeData[index, 5] = (tPoly-tIPP)/abs(tIPP)
            
            areApprox( polyAns, ippAns )
        end
    end
    
    return timeData
end
# Out:
# testspeed (generic function with 1 method)

# %%
times = testspeed(logspace(2,7, 20), (12, 32, 56, 108), 4);

# %%
plot(   times, x="Samples", y="Relative",
        Guide.title("Native Polyphase Interploation"),
        Guide.xlabel("Signal Length"),
        Guide.ylabel("Time Relative to IPP (lower is better)"),
        color="Taps",
        Scale.x_log10,
        Geom.line,
        Scale.discrete_color()
)
# Out:
# Plot(...)
